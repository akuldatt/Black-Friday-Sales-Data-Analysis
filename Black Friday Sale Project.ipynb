# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df =pd.read_csv('BlackFriday.csv')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
# Deleting the category as it has many Null values
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# # Analysing Each Column Using Pandas

# %%
# Finding Total Unique Values in that Column[Unique Coustomer]
df['User_ID'].nunique()
# Out:
# 5891

# %%
# Finding all Unique Values in that Column
df ['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00038842',
#        'P00295642', 'P00091742'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# 9333.859852635065

# %%
for column in df.columns:
    print(column ,':', df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [markdown]
# # Analyzing Gender Column

# %%
for column in df.columns:
    print(df[column].nunique(), '\t: ', column)
# Out:
# 5891 	:  User_ID
# 3623 	:  Product_ID
# 2 	:  Gender
# 7 	:  Age
# 21 	:  Occupation
# 3 	:  City_Category
# 5 	:  Stay_In_Current_City_Years
# 2 	:  Marital_Status
# 18 	:  Product_Category_1
# 17959 	:  Purchase

# %%
data = pd.DataFrame({'Ratio' : [len(df[df['Gender'] == 'M']), len(df[df['Gender'] == 'F'])]}, index = ['Male','Female'])

data.plot.pie( y = 'Ratio', figsize = (6,6), autopct = '%.1f')
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot(kind = 'pie' ,
                                 autopct ='%.1f',
                                 title = 'Gender Ration',
                                 figsize = (6,6))
# Out:
# <Axes: title={'center': 'Gender Ration'}>

# %%
df.groupby('Gender').size().plot(kind = 'bar',
                                 title = 'Gender Ration',
                                 figsize = (6,6))
# Out:
# <Axes: title={'center': 'Gender Ration'}, xlabel='Gender'>

# %%
df.groupby('Gender').size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind = 'pie', autopct = "%0.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df = df[pd.to_numeric(df['Purchase'], errors='coerce').notnull()]
df.groupby('Gender')['Purchase'].mean().plot(kind='pie', autopct="%0.1f")
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# # Analysing Age & Marital Status

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df.groupby('Age').size().plot(kind = 'pie' , autopct = '%0.1f' , title = 'Age Distribution', figsize = (6,6))
# Out:
# <Axes: title={'center': 'Age Distribution'}>

# %%
df.groupby('Age').size().plot(kind = 'bar'  , title = 'Purchase Distribution by Age', figsize = (12,6))
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
lst = []
for i in df['Age'].unique():
    lst.append([i,df[df['Age'] == i]['Product_ID'].nunique()])
lst

data = pd.DataFrame(lst , columns = ['Age','Products'])

# %%
# No. of Products According Age
data.plot.bar(x = 'Age',figsize = (8,6) ,title = 'No. of Products According Age'  )
# Out:
# <Axes: title={'center': 'No. of Products According Age'}, xlabel='Age'>

# %%
# Amount Spend by Age
df.groupby('Age').sum()['Purchase'].plot(kind = 'bar', figsize = (12,6), title = 'Amount Spend by Age')
# Out:
# <Axes: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %%
df = df[pd.to_numeric(df['Purchase'], errors='coerce').notnull()]
df.groupby('Age')['Purchase'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby('Age')['Purchase'].mean().plot(kind='pie', autopct = '%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size().plot(kind = 'pie', autopct = '%.01f' , figsize = (6,6) )
# Out:
# <Axes: >

# %% [markdown]
# # Multi Column Analysis

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = 'Age' , hue = 'Gender' , data =df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = 'Gender' , hue = 'Age' , data =df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = 'Age' , hue = 'Marital_Status' , data =df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = 'Marital_Status' , hue = 'Age' , data =df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (6,6)})
sns.countplot(x = 'Gender' , hue = 'Marital_Status' , data =df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (6,6)})
sns.countplot(x = 'Marital_Status' , hue = 'Gender' , data =df )
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot( x = df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot( x = 'City_Category' , hue ='Age', data =df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot( x = 'Age' , hue ='City_Category', data =df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot( x = 'City_Category' , hue ='Gender', data =df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot( x = 'Gender' , hue ='City_Category', data =df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot( x = 'City_Category' , hue ='Marital_Status', data =df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot( x = 'Marital_Status' , hue ='City_Category', data =df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind = 'pie' , autopct = '%0.1f' ,title = 'City Ratio')
# Out:
# <Axes: title={'center': 'City Ratio'}>

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind = 'bar', title ='Total Purchase According to City Category')
# Out:
# <Axes: title={'center': 'Total Purchase According to City Category'}, xlabel='City_Category'>

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind = 'pie' , autopct = '%0.1f', title ='Total Purchase According to City Category')
# Out:
# <Axes: title={'center': 'Total Purchase According to City Category'}, ylabel='Purchase'>

# %%
df = df[pd.to_numeric(df['Purchase'], errors='coerce').notnull()]
df.groupby('City_Category')['Purchase'].mean().plot(kind='pie', autopct="%0.1f", title = 'Average Spend')
# Out:
# <Axes: title={'center': 'Average Spend'}, ylabel='Purchase'>

# %% [markdown]
# # Occupation and Products Analysis

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind = 'pie', autopct = '%0.1f' , title = 'Stay_In_Current_City_Years')
# Out:
# <Axes: title={'center': 'Stay_In_Current_City_Years'}>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'Gender' , data =df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
 sns.countplot(x ='Stay_In_Current_City_Years' , hue = 'Marital_Status', data =df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'City_Category', hue ='Age', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind = 'bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df = df[pd.to_numeric(df['Purchase'], errors = 'coerce').notnull()]
df.groupby('Stay_In_Current_City_Years')['Purchase'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %% [markdown]
# # Occupation

# %%
sns.countplot(x = df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind = 'bar', figsize = (12,6), title = 'Occupation')
# Out:
# <Axes: title={'center': 'Occupation'}, xlabel='Occupation'>

# %%
df.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind = 'bar', figsize = (12,6), title = 'Total Purchase According to Occupation')
# Out:
# <Axes: title={'center': 'Total Purchase According to Occupation'}, xlabel='Occupation'>

# %%
df = df[pd.to_numeric(df['Purchase'],errors = 'coerce').notnull()]
df.groupby('Occupation')['Purchase'].mean().sort_values().plot(kind = 'bar')

df = df[pd.to_numeric(df['Purchase'],errors = 'coerce').notnull()]
df.groupby('Occupation')['Purchase'].mean().sort_values()
# Out:
# Occupation
# 9     8714.335934
# 19    8754.249162
# 20    8881.099514
# 1     9017.703095
# 2     9025.938982
# 10    9052.836410
# 0     9186.946726
# 18    9233.671418
# 3     9238.077277
# 4     9279.026742
# 11    9299.467190
# 6     9336.378620
# 5     9388.848978
# 13    9424.449391
# 16    9457.133118
# 7     9502.175276
# 14    9568.536426
# 8     9576.508530
# 15    9866.239925
# 12    9883.052460
# 17    9906.378997
# Name: Purchase, dtype: float64

# %%
sns.countplot(x ='Occupation', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x ='Occupation', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x ='Occupation', hue = 'Age', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df = df[pd.to_numeric(df['Purchase'] , errors = 'coerce').notnull()]
df.groupby('Product_Category_1')['Purchase'].mean().sort_values().plot(kind = 'bar' )

df.groupby('Product_Category_1')['Purchase'].mean().sort_values()
# Out:
# Product_Category_1
# 13      722.619485
# 12     1351.195613
# 4      2328.862886
# 18     2975.307642
# 11     4682.933556
# 5      6238.004045
# 8      7497.354850
# 3     10096.841705
# 17    10156.440917
# 2     11255.680752
# 14    13145.452000
# 1     13607.701495
# 16    14764.157471
# 15    14776.422215
# 9     15538.297030
# 6     15837.893573
# 7     16373.830153
# 10    19679.974364
# Name: Purchase, dtype: float64

# %%
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df = df[pd.to_numeric(df['Purchase'],  errors = 'coerce').notnull()]
df.groupby('Product_ID')['Purchase'].mean().nlargest(10).sort_values().plot(kind ='bar')

df.groupby('Product_ID')['Purchase'].mean().nlargest(10).sort_values()
# Out:
# Product_ID
# P00087042    20079.646809
# P00052842    20136.811983
# P00341542    20291.000000
# P00074542    20323.000000
# P00117642    20453.368557
# P00119342    20454.296053
# P00116142    20478.264753
# P00200642    20479.229885
# P00085342    20993.804428
# P00086242    21297.865672
# Name: Purchase, dtype: float64

# %% [markdown]
# # Combining Gender & Marital Status

# %%
lst = []
for i in range(len(df)):
    lst.append(df['Gender'][i] +'_'+ str(df['Marital_Status'][i]))

lst
# Out:
# ['F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_0',
#  'M_0',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_0',
#  'M_0',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'F_1',
#  'F_1',
#  'M_0',
#  'M_0',
#  'M_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
# ...

# %%
df['Marital+Gender'] = lst

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   Martital+Gender Marital+Gender
# 0             F_0            F_0
# 1             F_0            F_0
# 2             F_0            F_0
# ...

# %%
sns.countplot(x = df['Marital+Gender'])
# Out:
# <Axes: xlabel='Marital+Gender', ylabel='count'>

# %%
sns.countplot(x = 'Marital+Gender', hue = 'Age' , data = df)
# Out:
# <Axes: xlabel='Marital+Gender', ylabel='count'>

# %%
sns.countplot(x = 'Product_Category_1', hue = 'Marital+Gender' , data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'Marital+Gender'  , data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'City_Category' , hue = 'Marital+Gender'  , data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = 'Occupation', hue = 'Marital+Gender'  , data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Marital+Gender')['Purchase'].size().plot(kind = 'pie', autopct ='%.01f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Marital+Gender')['Purchase'].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Marital+Gender'>

# %%
df.groupby('Marital+Gender')['Purchase'].sum().plot(kind = 'pie', autopct ='%.01f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Marital+Gender')['Purchase'].mean().plot(kind = 'pie', autopct ='%.01f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Marital+Gender')['Purchase'].size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Marital+Gender'>
